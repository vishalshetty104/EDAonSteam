# %% [markdown]
# **Importing required libraries**

# %%
import numpy as np 
import pandas as pd
import re #regular expression module

from ast import literal_eval #needed for processing dicts and lists
pd.set_option("max_columns", 100)

# %% [markdown]
# # Steam data
# Cleaning data recieved from steam api

# %%
steam_raw = pd.read_csv('/content/drive/MyDrive/DA Project(EDA on Steam)/steam_app_data.csv') #importing raw data

print('Rows:', steam_raw.shape[0]) #returns no of rows
print('Columns:', steam_raw.shape[1]) #returns no of columns

steam_raw.head() #displays first 5 rows
# Out:
# Rows: 29235
# Columns: 39
#    type                       name  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support  dlc                               detailed_description  \
# 0                NaN  NaN  Play the world's number 1 online action game. ...
# 1                NaN  NaN  One of the most popular online action games of...
# 2                NaN  NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  NaN  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  fullgame  \
# 0  Play the world's number 1 online action game. ...       NaN
# 1  One of the most popular online action games of...       NaN
# 2  Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3  Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4  Return to the Black Mesa Research Facility as ...       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements legal_notice drm_notice  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
#
#   ext_user_account_notice            developers publishers demos  \
# 0                     NaN             ['Valve']  ['Valve']   NaN
# 1                     NaN             ['Valve']  ['Valve']   NaN
# 2                     NaN             ['Valve']  ['Valve']   NaN
# 3                     NaN             ['Valve']  ['Valve']   NaN
# 4                     NaN  ['Gearbox Software']  ['Valve']   NaN
#
#                                       price_overview packages  \
# 0  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic reviews  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                NaN     NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies   recommendations  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 65735}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 2802}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 1992}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN    {'total': 931}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 4355}
#
#    achievements                                   release_date  \
# 0  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'total': 0}  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'total': 0}  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'total': 0}  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# Checking for null values

# %%
total_null = steam_raw.isnull().sum()
total_null
# Out:
# type                         149
# name                           1
# steam_appid                    0
# required_age                 149
# is_free                      149
# controller_support         23237
# dlc                        24260
# detailed_description         175
# about_the_game               175
# short_description            175
# fullgame                   29235
# supported_languages          163
# header_image                 149
# website                     9983
# pc_requirements              149
# mac_requirements             149
# linux_requirements           149
# legal_notice               19168
# drm_notice                 29077
# ext_user_account_notice    28723
# developers                   264
# publishers                   149
# demos                      27096
# price_overview              3712
# packages                    3370
# package_groups               149
# platforms                    149
# metacritic                 26254
# reviews                    23330
# categories                   714
# genres                       196
# screenshots                  177
# movies                      2078
# recommendations            22507
# achievements                2381
# release_date                 149
# support_info                 149
# background                   177
# content_descriptors          149
# dtype: int64

# %% [markdown]
# Finding columns that have insufficient data

# %%
threshold = steam_raw.shape[0]//2 
print(str(threshold) + " rows")
print("columns to drop: "+ str(steam_raw.columns[total_null > threshold])) #columns where no of null/missing values is more than half
# Out:
# 14617 rows
# columns to drop: Index(['controller_support', 'dlc', 'fullgame', 'legal_notice', 'drm_notice',
#        'ext_user_account_notice', 'demos', 'metacritic', 'reviews',
#        'recommendations'],
#       dtype='object')

# %% [markdown]
# Processing 'Type' column

# %%
steam_raw['type'].value_counts(dropna=False)
# Out:
# game    29086
# NaN       149
# Name: type, dtype: int64

# %% [markdown]
# **Processing 'Name' column**
#
# Checking name column for null and 'None' values

# %%
steam_raw[(steam_raw['name'].isnull()) | (steam_raw['name'] == 'none')]
# Out:
#       type  name  steam_appid  required_age is_free controller_support  dlc  \
# 4918  game  none       339860           0.0   False                NaN  NaN
# 6779  game  none       385020           0.0   False                NaN  NaN
# 7235  game   NaN       396420           0.0    True                NaN  NaN
# 7350  game  none       398970           0.0   False                NaN  NaN
#
#                                    detailed_description  \
# 4918                                                NaN
# 6779                   - discontinued - (please remove)
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。<b...
# 7350                                                NaN
#
#                                          about_the_game  \
# 4918                                                NaN
# 6779                   - discontinued - (please remove)
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。<b...
# 7350                                                NaN
#
#                                       short_description  fullgame  \
# 4918                                                NaN       NaN
# 6779                   - discontinued - (please remove)       NaN
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。 村...       NaN
# 7350                                                NaN       NaN
#
#                                     supported_languages  \
# 4918  English<strong>*</strong><br><strong>*</strong...
# 6779  English, French, Italian, German, Spanish - Sp...
# 7235                                                NaN
# 7350  English<strong>*</strong><br><strong>*</strong...
#
#                                            header_image website  \
# 4918  https://steamcdn-a.akamaihd.net/steam/apps/339...     NaN
# 6779  https://steamcdn-a.akamaihd.net/steam/apps/385...     NaN
# 7235  https://steamcdn-a.akamaihd.net/steam/apps/396...     NaN
# 7350  https://steamcdn-a.akamaihd.net/steam/apps/398...     NaN
#
#                                         pc_requirements  \
# 4918  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7235  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                        mac_requirements  \
# 4918                                                 []
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7235                                                 []
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      linux_requirements legal_notice  \
# 4918                                                 []          NaN
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
# 7235                                                 []          NaN
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
#
#      drm_notice ext_user_account_notice developers publishers  \
# 4918        NaN                     NaN        NaN       ['']
# 6779        NaN                     NaN   ['none']       ['']
# 7235        NaN                     NaN        NaN       ['']
# 7350        NaN                     NaN   ['none']   ['none']
#
#                                        demos price_overview packages  \
# 4918                                     NaN            NaN      NaN
# 6779                                     NaN            NaN      NaN
# 7235                                     NaN            NaN      NaN
# 7350  [{'appid': 516340, 'description': ''}]            NaN      NaN
#
#      package_groups                                        platforms  \
# 4918             []  {'windows': True, 'mac': False, 'linux': False}
# 6779             []    {'windows': True, 'mac': True, 'linux': True}
# 7235             []  {'windows': True, 'mac': False, 'linux': False}
# 7350             []    {'windows': True, 'mac': True, 'linux': True}
#
#      metacritic reviews                                         categories  \
# 4918        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
# 6779        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
# 7235        NaN     NaN                                                NaN
# 7350        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                  genres screenshots movies  \
# 4918  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
# 6779  [{'id': '4', 'description': 'Casual'}, {'id': ...         NaN    NaN
# 7235                                                NaN         NaN    NaN
# 7350  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
#
#      recommendations                                       achievements  \
# 4918             NaN  {'total': 3, 'highlighted': [{'name': 'Master ...
# 6779             NaN                                       {'total': 0}
# 7235             NaN                                       {'total': 0}
# 7350             NaN  {'total': 35, 'highlighted': [{'name': "They'v...
#
#                                         release_date  \
# 4918  {'coming_soon': False, 'date': '27 Feb, 2015'}
# 6779   {'coming_soon': False, 'date': '4 Nov, 2015'}
# 7235   {'coming_soon': False, 'date': '1 Nov, 2016'}
# 7350   {'coming_soon': False, 'date': '5 Nov, 2015'}
#
#                   support_info background         content_descriptors
# 4918  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 6779  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 7235  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 7350  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}

# %% [markdown]
# **Checking for duplicate values**

# %%
duplicate_rows = steam_raw[steam_raw.duplicated()]

print('Duplicate rows to remove:', duplicate_rows.shape[0])

duplicate_rows.head(3)
# Out:
# Duplicate rows to remove: 7
#      type                     name  steam_appid  required_age is_free  \
# 31   game  SiN Episodes: Emergence         1300           0.0   False
# 32   game  SiN Episodes: Emergence         1300           0.0   False
# 356  game   Jagged Alliance 2 Gold         1620           0.0   False
#
#     controller_support  dlc  \
# 31                 NaN  NaN
# 32                 NaN  NaN
# 356                NaN  NaN
#
#                                   detailed_description  \
# 31   You are John Blade, commander of HardCorps, an...
# 32   You are John Blade, commander of HardCorps, an...
# 356  <p>The small country of Arulco has been taken ...
#
#                                         about_the_game  \
# 31   You are John Blade, commander of HardCorps, an...
# 32   You are John Blade, commander of HardCorps, an...
# 356  <p>The small country of Arulco has been taken ...
#
#                                      short_description  fullgame  \
# 31   You are John Blade, commander of HardCorps, an...       NaN
# 32   You are John Blade, commander of HardCorps, an...       NaN
# 356  The small country of Arulco has been taken ove...       NaN
#
#           supported_languages  \
# 31   English, Russian, French
# 32   English, Russian, French
# 356                   English
#
#                                           header_image  \
# 31   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 32   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 356  https://steamcdn-a.akamaihd.net/steam/apps/162...
#
#                              website  \
# 31                               NaN
# 32                               NaN
# 356  http://www.jaggedalliance2.com/
#
#                                        pc_requirements mac_requirements  \
# 31   {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...               []
# 32   {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...               []
# 356  {'minimum': '<p><strong>Minimum Configuration:...               []
#
#     linux_requirements legal_notice drm_notice ext_user_account_notice  \
# 31                  []          NaN        NaN                     NaN
# 32                  []          NaN        NaN                     NaN
# 356                 []          NaN        NaN                     NaN
#
#                    developers                publishers demos  \
# 31   ['Ritual Entertainment']  ['Ritual Entertainment']   NaN
# 32   ['Ritual Entertainment']  ['Ritual Entertainment']   NaN
# 356        ['Strategy First']        ['Strategy First']   NaN
#
#                                         price_overview packages  \
# 31   {'currency': 'GBP', 'initial': 719, 'final': 7...     [70]
# 32   {'currency': 'GBP', 'initial': 719, 'final': 7...     [70]
# 356  {'currency': 'GBP', 'initial': 1499, 'final': ...     [94]
#
#                                         package_groups  \
# 31   [{'name': 'default', 'title': 'Buy SiN Episode...
# 32   [{'name': 'default', 'title': 'Buy SiN Episode...
# 356  [{'name': 'default', 'title': 'Buy Jagged Alli...
#
#                                            platforms  \
# 31   {'windows': True, 'mac': False, 'linux': False}
# 32   {'windows': True, 'mac': False, 'linux': False}
# 356  {'windows': True, 'mac': False, 'linux': False}
#
#                                             metacritic reviews  \
# 31   {'score': 75, 'url': 'https://www.metacritic.c...     NaN
# 32   {'score': 75, 'url': 'https://www.metacritic.c...     NaN
# 356                                                NaN     NaN
#
#                                             categories  \
# 31   [{'id': 2, 'description': 'Single-player'}, {'...
# 32   [{'id': 2, 'description': 'Single-player'}, {'...
# 356        [{'id': 2, 'description': 'Single-player'}]
#
#                                        genres  \
# 31     [{'id': '1', 'description': 'Action'}]
# 32     [{'id': '1', 'description': 'Action'}]
# 356  [{'id': '2', 'description': 'Strategy'}]
#
#                                            screenshots movies recommendations  \
# 31   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 265}
# 32   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 265}
# 356  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             NaN
#
#      achievements                                    release_date  \
# 31   {'total': 0}  {'coming_soon': False, 'date': '10 May, 2006'}
# 32   {'total': 0}  {'coming_soon': False, 'date': '10 May, 2006'}
# 356  {'total': 0}   {'coming_soon': False, 'date': '6 Jul, 2006'}
#
#                  support_info  \
# 31   {'url': '', 'email': ''}
# 32   {'url': '', 'email': ''}
# 356  {'url': '', 'email': ''}
#
#                                             background  \
# 31   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 32   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 356  https://steamcdn-a.akamaihd.net/steam/apps/162...
#
#             content_descriptors
# 31   {'ids': [], 'notes': None}
# 32   {'ids': [], 'notes': None}
# 356  {'ids': [], 'notes': None}

# %% [markdown]
# **Dropping of Columns based on conditions above**

# %%
def drop_null_cols(df, thresh=0.5):
    #drop columns which have more than 50% missing values
    cutoff_count = len(df) * thresh
    
    return df.dropna(thresh=cutoff_count, axis=1)


def process_name_type(df):
    #remove null and 'none' values in name and type column and also drop type column
    df = df[df['type'].notnull()]
    
    df = df[df['name'].notnull()]
    df = df[df['name'] != 'none']
    
    df = df.drop('type', axis=1)
    
    return df
    

def process(df):
    #driver function
    
    # Creating a copy of original dataframe
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove columns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    
    return df

print(steam_raw.shape)
initial_processing = process(steam_raw)
print(initial_processing.shape)
initial_processing.head()
# Out:
# (29235, 39)
# (29075, 28)
#                         name  steam_appid  required_age is_free  \
# 0             Counter-Strike           10           0.0   False
# 1      Team Fortress Classic           20           0.0   False
# 2              Day of Defeat           30           0.0   False
# 3         Deathmatch Classic           40           0.0   False
# 4  Half-Life: Opposing Force           50           0.0   False
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers                                     price_overview packages  \
# 0  ['Valve']  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# **Processing Age column**
#
# Creating age-range instead of individual value

# %%
initial_processing['required_age'].value_counts(dropna=False).sort_index()
# Out:
# 0.0       28431
# 1.0           1
# 3.0          10
# 4.0           2
# 5.0           1
# 6.0           1
# 7.0           8
# 10.0          3
# 11.0          4
# 12.0         72
# 13.0         21
# 14.0          4
# 15.0         39
# 16.0        141
# 17.0         47
# 18.0        288
# 20.0          1
# 1818.0        1
# Name: required_age, dtype: int64

# %%
def process_age(df):
    """Format ratings in age column to be in line with the PEGI Age Ratings system."""
    # PEGI Age ratings: 3, 7, 12, 16, 18
    cut_points = [-1, 0, 3, 7, 12, 16, 2000] #boundary values for ages
    label_values = [0, 3, 7, 12, 16, 18] #age range
    
    df['required_age'] = pd.cut(df['required_age'], bins=cut_points, labels=label_values)
    
    return df


age_df = process_age(initial_processing)
age_df['required_age'].value_counts().sort_index()
# Out:
# 0     28431
# 3        11
# 7        12
# 12       79
# 16      205
# 18      337
# Name: required_age, dtype: int64

# %% [markdown]
# **Processing Platform column**

# %%
age_df['platforms'].head()
# Out:
# 0    {'windows': True, 'mac': True, 'linux': True}
# 1    {'windows': True, 'mac': True, 'linux': True}
# 2    {'windows': True, 'mac': True, 'linux': True}
# 3    {'windows': True, 'mac': True, 'linux': True}
# 4    {'windows': True, 'mac': True, 'linux': True}
# Name: platforms, dtype: object

# %%
platforms_first_row = age_df['platforms'].iloc[0]
eval_first_row = literal_eval(platforms_first_row)
eval_first_row
# Out:
# {'windows': True, 'mac': True, 'linux': True}

# %%
platforms = {'windows': True, 'mac': True, 'linux': False}

# return only keys with true
print([x for x in platforms.keys() if platforms[x]])

';'.join(x for x in platforms.keys() if platforms[x])
# Out:
# ['windows', 'mac']
# 'windows;mac'

# %%
def process_platforms(df):
    # convert dict format to string for further processing
    df = df.copy()
    
    def parse_platforms(x):
        
        d = literal_eval(x)
        
        return ';'.join(platform for platform in d.keys() if d[platform]) 
    
    df['platforms'] = df['platforms'].apply(parse_platforms) #apply is used to call function for each row
    
    return df


platforms_df = process_platforms(age_df)
platforms_df['platforms'].value_counts()
# Out:
# windows              19887
# windows;mac;linux     4851
# windows;mac           3687
# windows;linux          643
# mac                      5
# mac;linux                1
# linux                    1
# Name: platforms, dtype: int64

# %%
platforms_df
# Out:
#                              name  steam_appid required_age is_free  \
# 0                  Counter-Strike           10            0   False
# 1           Team Fortress Classic           20            0   False
# 2                   Day of Defeat           30            0   False
# 3              Deathmatch Classic           40            0   False
# 4       Half-Life: Opposing Force           50            0   False
# ...                           ...          ...          ...     ...
# 29230             Room of Pandora      1065230            0   False
# 29231                   Cyber Gun      1065570            0   False
# 29232            Super Star Blast      1065650            0   False
# 29233  New Yankee 7: Deer Hunters      1066700            0   False
# 29234                   Rune Lord      1069460            0   False
#
#                                     detailed_description  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 29230  <img src="https://steamcdn-a.akamaihd.net/stea...
# 29231  Have you ever been so lonely that no one but y...
# 29232  <strong>Super Star Blast </strong>is a space b...
# 29233  Pursue a snow-white deer through an enchanted ...
# 29234  A portal has opened and dark magic is pouring ...
#
#                                           about_the_game  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 29230  <img src="https://steamcdn-a.akamaihd.net/stea...
# 29231  Have you ever been so lonely that no one but y...
# 29232  <strong>Super Star Blast </strong>is a space b...
# 29233  Pursue a snow-white deer through an enchanted ...
# 29234  A portal has opened and dark magic is pouring ...
#
#                                        short_description  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 29230  The Room of Pandora is a third-person interact...
# 29231  Cyber Gun is a hardcore first-person shooter w...
# 29232  Super Star Blast is a space based game with ch...
# 29233  Pursue a snow-white deer through an enchanted ...
# 29234  A portal has opened and dark magic is pouring ...
#
#                                      supported_languages  \
# 0      English<strong>*</strong>, French<strong>*</st...
# 1      English, French, German, Italian, Spanish - Sp...
# 2      English, French, German, Italian, Spanish - Spain
# 3      English, French, German, Italian, Spanish - Sp...
# 4                        English, French, German, Korean
# ...                                                  ...
# 29230  English, Japanese, Simplified Chinese, Traditi...
# 29231                                            English
# 29232  English<strong>*</strong><br><strong>*</strong...
# 29233                   English, German, Korean, Russian
# 29234  English, French, Italian, German, Spanish - Sp...
#
#                                             header_image  \
# 0      https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1      https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2      https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3      https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4      https://steamcdn-a.akamaihd.net/steam/apps/50/...
# ...                                                  ...
# 29230  https://steamcdn-a.akamaihd.net/steam/apps/106...
# 29231  https://steamcdn-a.akamaihd.net/steam/apps/106...
# 29232  https://steamcdn-a.akamaihd.net/steam/apps/106...
# 29233  https://steamcdn-a.akamaihd.net/steam/apps/106...
# 29234  https://steamcdn-a.akamaihd.net/steam/apps/106...
#
#                                              website  \
# 0                                                NaN
# 1                                                NaN
# 2                        http://www.dayofdefeat.com/
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 29230                                            NaN
# 29231                                            NaN
# 29232        http://entwickler-x.de/super-star-blast
# 29233  https://steamcommunity.com/groups/alawargames
# 29234  https://steamcommunity.com/groups/alawargames
#
#                                          pc_requirements  \
# 0      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# ...                                                  ...
# 29230  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 29231  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 29232  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 29233  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 29234  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 0      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# ...                                                  ...
# 29230                                                 []
# 29231                                                 []
# 29232                                                 []
# 29233  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 29234  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                       linux_requirements  \
# 0      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 1      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 2      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 3      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 4      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# ...                                                  ...
# 29230                                                 []
# 29231                                                 []
# 29232                                                 []
# 29233                                                 []
# 29234                                                 []
#
#                    developers                publishers  \
# 0                   ['Valve']                 ['Valve']
# 1                   ['Valve']                 ['Valve']
# 2                   ['Valve']                 ['Valve']
# 3                   ['Valve']                 ['Valve']
# 4        ['Gearbox Software']                 ['Valve']
# ...                       ...                       ...
# 29230         ['SHEN JIAWEI']           ['SHEN JIAWEI']
# 29231      ['Semyon Maximov']      ['BekkerDev Studio']
# 29232         ['EntwicklerX']           ['EntwicklerX']
# 29233  ['Yustas Game Studio']  ['Alawar Entertainment']
# 29234    ['Adept Studios GD']  ['Alawar Entertainment']
#
#                                           price_overview          packages  \
# 0      {'currency': 'GBP', 'initial': 719, 'final': 7...               [7]
# 1      {'currency': 'GBP', 'initial': 399, 'final': 3...              [29]
# 2      {'currency': 'GBP', 'initial': 399, 'final': 3...              [30]
# 3      {'currency': 'GBP', 'initial': 399, 'final': 3...              [31]
# 4      {'currency': 'GBP', 'initial': 399, 'final': 3...              [32]
# ...                                                  ...               ...
# 29230  {'currency': 'GBP', 'initial': 209, 'final': 1...          [356453]
# 29231  {'currency': 'GBP', 'initial': 169, 'final': 1...          [356591]
# 29232  {'currency': 'GBP', 'initial': 399, 'final': 3...          [356634]
# 29233  {'currency': 'GBP', 'initial': 519, 'final': 5...  [357074, 359118]
# 29234  {'currency': 'GBP', 'initial': 519, 'final': 4...  [358365, 360810]
#
#                                           package_groups          platforms  \
# 0      [{'name': 'default', 'title': 'Buy Counter-Str...  windows;mac;linux
# 1      [{'name': 'default', 'title': 'Buy Team Fortre...  windows;mac;linux
# 2      [{'name': 'default', 'title': 'Buy Day of Defe...  windows;mac;linux
# 3      [{'name': 'default', 'title': 'Buy Deathmatch ...  windows;mac;linux
# 4      [{'name': 'default', 'title': 'Buy Half-Life: ...  windows;mac;linux
# ...                                                  ...                ...
# 29230  [{'name': 'default', 'title': 'Buy Room of Pan...            windows
# 29231  [{'name': 'default', 'title': 'Buy Cyber Gun',...            windows
# 29232  [{'name': 'default', 'title': 'Buy Super Star ...            windows
# 29233  [{'name': 'default', 'title': 'Buy New Yankee ...        windows;mac
# 29234  [{'name': 'default', 'title': 'Buy Rune Lord',...        windows;mac
#
#                                               categories  \
# 0      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4      [{'id': 2, 'description': 'Single-player'}, {'...
# ...                                                  ...
# 29230  [{'id': 2, 'description': 'Single-player'}, {'...
# 29231        [{'id': 2, 'description': 'Single-player'}]
# 29232  [{'id': 2, 'description': 'Single-player'}, {'...
# 29233  [{'id': 2, 'description': 'Single-player'}, {'...
# 29234  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres  \
# 0                 [{'id': '1', 'description': 'Action'}]
# 1                 [{'id': '1', 'description': 'Action'}]
# 2                 [{'id': '1', 'description': 'Action'}]
# 3                 [{'id': '1', 'description': 'Action'}]
# 4                 [{'id': '1', 'description': 'Action'}]
# ...                                                  ...
# 29230  [{'id': '25', 'description': 'Adventure'}, {'i...
# 29231  [{'id': '1', 'description': 'Action'}, {'id': ...
# 29232  [{'id': '1', 'description': 'Action'}, {'id': ...
# 29233  [{'id': '25', 'description': 'Adventure'}, {'i...
# 29234  [{'id': '25', 'description': 'Adventure'}, {'i...
#
#                                              screenshots  \
# 0      [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1      [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2      [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 3      [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 4      [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# ...                                                  ...
# 29230  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 29231  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 29232  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 29233  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 29234  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                   movies  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29230  [{'id': 256747452, 'name': 'Video', 'thumbnail...
# 29231  [{'id': 256747487, 'name': 'Game Trailer', 'th...
# 29232  [{'id': 256747530, 'name': 'Gameplay Trailer',...
# 29233  [{'id': 256747638, 'name': 'Main Trailer', 'th...
# 29234  [{'id': 256748098, 'name': 'Main Trailer', 'th...
#
#                                             achievements  \
# 0                                           {'total': 0}
# 1                                           {'total': 0}
# 2                                           {'total': 0}
# 3                                           {'total': 0}
# 4                                           {'total': 0}
# ...                                                  ...
# 29230  {'total': 7, 'highlighted': [{'name': 'THE FIR...
# 29231                                                NaN
# 29232  {'total': 24, 'highlighted': [{'name': 'Power ...
# 29233                                       {'total': 0}
# 29234                                       {'total': 0}
#
#                                          release_date  \
# 0       {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1       {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2       {'coming_soon': False, 'date': '1 May, 2003'}
# 3       {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4       {'coming_soon': False, 'date': '1 Nov, 1999'}
# ...                                               ...
# 29230  {'coming_soon': False, 'date': '24 Apr, 2019'}
# 29231  {'coming_soon': False, 'date': '23 Apr, 2019'}
# 29232  {'coming_soon': False, 'date': '24 Apr, 2019'}
# 29233  {'coming_soon': False, 'date': '17 Apr, 2019'}
# 29234  {'coming_soon': False, 'date': '24 Apr, 2019'}
#
#                                             support_info  \
# 0      {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                               {'url': '', 'email': ''}
# 2                               {'url': '', 'email': ''}
# 3                               {'url': '', 'email': ''}
# 4      {'url': 'https://help.steampowered.com', 'emai...
# ...                                                  ...
# 29230  {'url': 'https://goldlogsh.wixsite.com/myapps'...
# 29231        {'url': '', 'email': 'piziroggg@gmail.com'}
# 29232  {'url': 'http://www.entwickler-x.de', 'email':...
# 29233  {'url': 'http://www.alawar.com', 'email': 'ste...
# 29234  {'url': 'http://www.alawar.com', 'email': 'ste...
#
#                                               background  \
# 0      https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1      https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2      https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3      https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4      https://steamcdn-a.akamaihd.net/steam/apps/50/...
# ...                                                  ...
# 29230  https://steamcdn-a.akamaihd.net/steam/apps/106...
# 29231  https://steamcdn-a.akamaihd.net/steam/apps/106...
# 29232  https://steamcdn-a.akamaihd.net/steam/apps/106...
# 29233  https://steamcdn-a.akamaihd.net/steam/apps/106...
# 29234  https://steamcdn-a.akamaihd.net/steam/apps/106...
#
#                                      content_descriptors
# 0      {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1      {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                             {'ids': [], 'notes': None}
# 3                             {'ids': [], 'notes': None}
# 4                             {'ids': [], 'notes': None}
# ...                                                  ...
# 29230                         {'ids': [], 'notes': None}
# 29231                         {'ids': [], 'notes': None}
# 29232                         {'ids': [], 'notes': None}
# 29233                         {'ids': [], 'notes': None}
# 29234                         {'ids': [], 'notes': None}
#
# [29075 rows x 28 columns]

# %% [markdown]
# **Processing Price Column**
#
# Checking is_free and price_overview columns

# %%
#check null values
print(platforms_df['price_overview'].isnull().sum())

#check if they are free instead
free_and_null_price = platforms_df[(platforms_df['is_free']) & (platforms_df['price_overview'].isnull())]
free_and_null_price.shape[0]
# Out:
# 3559
# 2713

# %%
def process_price(df):
    """Process price_overview column into formatted price column, and take care of package columns."""
    df = df.copy()
    
    def parse_price(x):
        if x is not np.nan:
            return literal_eval(x)
        else:
            return {'currency': 'GBP', 'initial': -1}
    
    # evaluate as dictionary and set to -1 if missing
    df['price_overview'] = df['price_overview'].apply(parse_price)
    
    # create columns from currency and initial values
    df['currency'] = df['price_overview'].apply(lambda x: x['currency'])
    df['price'] = df['price_overview'].apply(lambda x: x['initial'])
    
    # set price of free games to 0
    df.loc[df['is_free'], 'price'] = 0
    
    # remove non-GBP rows
    df = df[df['currency'] == 'GBP']
    
    # remove rows where price is -1
    df = df[df['price'] != -1]
    
    # change price to display in pounds (can apply to all now -1 rows removed)
    df['price'] /= 100
    
    # remove columns no longer needed
    df = df.drop(['is_free', 'currency', 'price_overview', 'packages', 'package_groups'], axis=1)
    
    return df


price_df = process_price(platforms_df)
price_df.head()
# Out:
#                         name  steam_appid required_age  \
# 0             Counter-Strike           10            0
# 1      Team Fortress Classic           20            0
# 2              Day of Defeat           30            0
# 3         Deathmatch Classic           40            0
# 4  Half-Life: Opposing Force           50            0
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers          platforms  \
# 0  ['Valve']  windows;mac;linux
# 1  ['Valve']  windows;mac;linux
# 2  ['Valve']  windows;mac;linux
# 3  ['Valve']  windows;mac;linux
# 4  ['Valve']  windows;mac;linux
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors  price
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...   7.19
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...   3.99
# 2                         {'ids': [], 'notes': None}   3.99
# 3                         {'ids': [], 'notes': None}   3.99
# 4                         {'ids': [], 'notes': None}   3.99

# %% [markdown]
# **Processing language column**

# %%
def process_language(df):
    """Process supported_languages column into a boolean 'is english' column."""
    df = df.copy()
    
    # drop rows with missing language data
    df = df.dropna(subset=['supported_languages'])
    
    df['english'] = df['supported_languages'].apply(lambda x: 1 if 'english' in x.lower() else 0) #if language contains 'english', put 1 else 0
    df = df.drop('supported_languages', axis=1)
    
    return df


language_df = process_language(price_df)
language_df[['name', 'english']].head()
# Out:
#                         name  english
# 0             Counter-Strike        1
# 1      Team Fortress Classic        1
# 2              Day of Defeat        1
# 3         Deathmatch Classic        1
# 4  Half-Life: Opposing Force        1

# %%
language_df['english'].value_counts()
# Out:
# 1    27699
# 0      522
# Name: english, dtype: int64

# %% [markdown]
# **Processing Developer and Publisher columns**

# %%
#Check for null values and empty lists
print('Developers null counts:', language_df['developers'].isnull().sum())
print('Developers empty list counts:', language_df[language_df['developers'] == "['']"].shape[0])

print('\nPublishers null counts:', language_df['publishers'].isnull().sum())
print('Publishers empty list counts:', language_df[language_df['publishers'] == "['']"].shape[0])
# Out:
# Developers null counts: 104
# Developers empty list counts: 0
#
# Publishers null counts: 0
# Publishers empty list counts: 213

# %%
#check for null-like values
language_df[(language_df['publishers'] == "['NA']") | (language_df['publishers'] == "['N/A']")].shape[0]
# Out:
# 12

# %%
def process_developers_and_publishers(df):
    """Parse columns as semicolon-separated string."""
    # remove rows with missing data (~ means not)
    df = df[(df['developers'].notnull()) & (df['publishers'] != "['']")].copy()
    df = df[~(df['developers'].str.contains(';')) & ~(df['publishers'].str.contains(';'))] #removes rows with ; in the list
    df = df[(df['publishers'] != "['NA']") & (df['publishers'] != "['N/A']")] #removes rows which have N/A as the value
    
    # modify developer and publisher column
    df['developer'] = df['developers'].apply(lambda x: ';'.join(literal_eval(x)))
    df['publisher'] = df['publishers'].apply(lambda x: ';'.join(literal_eval(x)))

    df = df.drop(['developers', 'publishers'], axis=1)
    
    return df

dev_pub_df = process_developers_and_publishers(language_df)
dev_pub_df[['name', 'steam_appid', 'developer', 'publisher']].head()
# Out:
#                         name  steam_appid         developer publisher
# 0             Counter-Strike           10             Valve     Valve
# 1      Team Fortress Classic           20             Valve     Valve
# 2              Day of Defeat           30             Valve     Valve
# 3         Deathmatch Classic           40             Valve     Valve
# 4  Half-Life: Opposing Force           50  Gearbox Software     Valve

# %% [markdown]
# **Processing Category and Genre Column**

# %%
#check for null values in categories and genres
print('Categories:\n')
print('Null values:', dev_pub_df['categories'].isnull().sum())
print()
print(dev_pub_df['categories'][0])

print('\nGenres:\n')
print('Null values:', dev_pub_df['genres'].isnull().sum())
print()
print(dev_pub_df['genres'].iloc[0])
print(dev_pub_df['genres'].iloc[1000])
# Out:
# Categories:
#
# Null values: 509
#
# [{'id': 1, 'description': 'Multi-player'}, {'id': 36, 'description': 'Online Multi-Player'}, {'id': 37, 'description': 'Local Multi-Player'}, {'id': 8, 'description': 'Valve Anti-Cheat enabled'}]
#
# Genres:
#
# Null values: 37
#
# [{'id': '1', 'description': 'Action'}]
# [{'id': '3', 'description': 'RPG'}, {'id': '2', 'description': 'Strategy'}]

# %%
def process_categories_and_genres(df):
    df = df.copy()
    df = df[(df['categories'].notnull()) & (df['genres'].notnull())]
    
    for col in ['categories', 'genres']:
        df[col] = df[col].apply(lambda x: ';'.join(item['description'] for item in literal_eval(x)))
    
    return df

cat_gen_df = process_categories_and_genres(dev_pub_df)
cat_gen_df[['steam_appid', 'categories', 'genres']].head()
# Out:
#    steam_appid                                         categories  genres
# 0           10  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1           20  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2           30              Multi-player;Valve Anti-Cheat enabled  Action
# 3           40  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4           50  Single-player;Multi-player;Valve Anti-Cheat en...  Action

# %% [markdown]
# **Processing achievements and content_descriptor column**

# %%
#check null values
print('Achievements null counts:', cat_gen_df['achievements'].isnull().sum())
print('Content Decsriptors null counts:', cat_gen_df['content_descriptors'].isnull().sum())

cat_gen_df[['name', 'achievements', 'content_descriptors']].iloc[8:13]
# Out:
# Achievements null counts: 1856
# Content Decsriptors null counts: 0
#                       name                                       achievements  \
# 8    Half-Life: Blue Shift                                       {'total': 0}
# 9              Half-Life 2  {'total': 33, 'highlighted': [{'name': 'Defian...
# 10  Counter-Strike: Source  {'total': 147, 'highlighted': [{'name': 'Someo...
# 11       Half-Life: Source                                       {'total': 0}
# 12   Day of Defeat: Source  {'total': 54, 'highlighted': [{'name': 'Double...
#
#                                   content_descriptors
# 8                          {'ids': [], 'notes': None}
# 9                          {'ids': [], 'notes': None}
# 10  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 11                         {'ids': [], 'notes': None}
# 12                         {'ids': [], 'notes': None}

# %%
#analysing content of achievements column
literal_eval(cat_gen_df['achievements'][9])

#better to use only the 'total' values and remove 'highlighted' values
# Out:
# {'total': 33,
#  'highlighted': [{'name': 'Defiant',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_hit_cancop_withcan.jpg'},
#   {'name': 'Submissive',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_put_canintrash.jpg'},
#   {'name': 'Malcontent',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_escape_apartmentraid.jpg'},
#   {'name': 'What cat?',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_break_miniteleporter.jpg'},
#   {'name': 'Trusty Hardware',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_get_crowbar.jpg'},
#   {'name': 'Barnacle Bowling',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_kill_barnacleswithbarrel.jpg'},
#   {'name': "Anchor's Aweigh!",
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_get_airboat.jpg'},
#   {'name': 'Heavy Weapons',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_get_airboatgun.jpg'},
#   {'name': 'Vorticough',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_find_vortigauntcave.jpg'},
#   {'name': 'Revenge!',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_kill_chopper.jpg'}]}

# %%
#analysing content descriptor column
cat_gen_df['content_descriptors'].value_counts().head(6)
#contains mostly none values so better to drop the column
# Out:
# {'ids': [], 'notes': None}                                                                                                                                                                  25398
# {'ids': [2, 5], 'notes': None}                                                                                                                                                                427
# {'ids': [1, 5], 'notes': None}                                                                                                                                                                250
# {'ids': [5], 'notes': None}                                                                                                                                                                   127
# {'ids': [1, 2, 5], 'notes': None}                                                                                                                                                             122
# {'ids': [2, 5], 'notes': 'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Frequent Violence or Gore, General Mature Content'}        8
# Name: content_descriptors, dtype: int64

# %%
def process_achievements_and_descriptors(df):
    """Parse as total number of achievements."""
    df = df.copy()
    
    df = df.drop('content_descriptors', axis=1) #dropping column as it is useless
    
    def parse_achievements(x):
        if x is np.nan:
            # missing data, assume has no achievements
            return 0
        else:
            # extract value from key 'total'
            return literal_eval(x)['total']
        
    df['achievements'] = df['achievements'].apply(parse_achievements)
    
    return df

achiev_df = process_achievements_and_descriptors(cat_gen_df)
achiev_df['achievements'].value_counts().head()
# Out:
# 0     11966
# 10      697
# 12      624
# 20      579
# 15      500
# Name: achievements, dtype: int64

# %%
achiev_df.isnull().sum()
# Out:
# name                       0
# steam_appid                0
# required_age               0
# detailed_description      14
# about_the_game            14
# short_description         14
# header_image               0
# website                 9348
# pc_requirements            0
# mac_requirements           0
# linux_requirements         0
# platforms                  0
# categories                 0
# genres                     0
# screenshots                5
# movies                  1724
# achievements               0
# release_date               0
# support_info               0
# background                 5
# price                      0
# english                    0
# developer                  0
# publisher                  0
# dtype: int64

# %% [markdown]
# **Processing release date column**

# %%
def process_release_date(df):
    df = df.copy()
    
    def eval_date(x):
        x = literal_eval(x)
        if x['coming_soon']:
            return '' # return blank string so can drop missing at end
        else:
            return x['date']
    
    df['release_date'] = df['release_date'].apply(eval_date)
    
    def parse_date(x):
        if re.search(r'[\d]{1,2} [A-Za-z]{3}, [\d]{4}', x): #checks for format like 15 Jan, 2021
            return x.replace(',', '')
        elif re.search(r'[A-Za-z]{3} [\d]{4}', x): #checks for format like Jan 2021
            return '1 ' + x
        elif x == '':
            return np.nan
        else:
            # Should be everything, print out anything left just in case
            print(x)
            
    df['release_date'] = df['release_date'].apply(parse_date)
    df['release_date'] = pd.to_datetime(df['release_date'], format='%d %b %Y', errors='coerce')
    
    df = df[df['release_date'].notnull()]
    
    return df

# %%
def process(df):
    #final method which contains all previous methods we wrote
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process columns
    df = process_name_type(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    df = process_language(df)
    df = process_developers_and_publishers(df)
    df = process_categories_and_genres(df)
    df = process_achievements_and_descriptors(df)  
    df = process_release_date(df)
    
    
    
    return df

steam_data = process(steam_raw)
steam_data.head()
# Out:
#                         name  steam_appid required_age  \
# 0             Counter-Strike           10            0
# 1      Team Fortress Classic           20            0
# 2              Day of Defeat           30            0
# 3         Deathmatch Classic           40            0
# 4  Half-Life: Opposing Force           50            0
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements          platforms  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
#
#   release_date                                       support_info  \
# 0   2000-11-01  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1   1999-04-01                           {'url': '', 'email': ''}
# 2   2003-05-01                           {'url': '', 'email': ''}
# 3   2001-06-01                           {'url': '', 'email': ''}
# 4   1999-11-01  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  price  english  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...   7.19        1
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...   3.99        1
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...   3.99        1
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...   3.99        1
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...   3.99        1
#
#           developer publisher
# 0             Valve     Valve
# 1             Valve     Valve
# 2             Valve     Valve
# 3             Valve     Valve
# 4  Gearbox Software     Valve

# %% [markdown]
# **Removing redundant columns**

# %%
final = steam_data.copy()
final = final.drop(['pc_requirements', 'mac_requirements', 'linux_requirements'], axis=1)
final.head()
# Out:
#                         name  steam_appid required_age  \
# 0             Counter-Strike           10            0
# 1      Team Fortress Classic           20            0
# 2              Day of Defeat           30            0
# 3         Deathmatch Classic           40            0
# 4  Half-Life: Opposing Force           50            0
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website          platforms  \
# 0                          NaN  windows;mac;linux
# 1                          NaN  windows;mac;linux
# 2  http://www.dayofdefeat.com/  windows;mac;linux
# 3                          NaN  windows;mac;linux
# 4                          NaN  windows;mac;linux
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
#
#   release_date                                       support_info  \
# 0   2000-11-01  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1   1999-04-01                           {'url': '', 'email': ''}
# 2   2003-05-01                           {'url': '', 'email': ''}
# 3   2001-06-01                           {'url': '', 'email': ''}
# 4   1999-11-01  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  price  english  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...   7.19        1
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...   3.99        1
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...   3.99        1
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...   3.99        1
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...   3.99        1
#
#           developer publisher
# 0             Valve     Valve
# 1             Valve     Valve
# 2             Valve     Valve
# 3             Valve     Valve
# 4  Gearbox Software     Valve

# %%
final = final.drop(['detailed_description','about_the_game','short_description','header_image','website','screenshots','movies','support_info','background'],axis=1)
final.isnull().sum()
# Out:
# name            0
# steam_appid     0
# required_age    0
# platforms       0
# categories      0
# genres          0
# achievements    0
# release_date    0
# price           0
# english         0
# developer       0
# publisher       0
# dtype: int64

# %%
final.to_csv('/content/drive/MyDrive/DA Project(EDA on Steam)/steam_data_clean.csv', index=False)

# %% [markdown]
# # SteamSpy data
#
# Cleaning data recieved from steamSpy api

# %%
import itertools

# %%
raw_steamspy_data = pd.read_csv('/content/drive/MyDrive/DA Project(EDA on Steam)/steamspy_data.csv')
raw_steamspy_data.head()
# Out:
#    appid                       name         developer publisher  score_rank  \
# 0     10             Counter-Strike             Valve     Valve         NaN
# 1     20      Team Fortress Classic             Valve     Valve         NaN
# 2     30              Day of Defeat             Valve     Valve         NaN
# 3     40         Deathmatch Classic             Valve     Valve         NaN
# 4     50  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever  \
# 0    124534      3339          0  10,000,000 .. 20,000,000            17612
# 1      3318       633          0   5,000,000 .. 10,000,000              277
# 2      3416       398          0   5,000,000 .. 10,000,000              187
# 3      1273       267          0   5,000,000 .. 10,000,000              258
# 4      5250       288          0   5,000,000 .. 10,000,000              624
#
#    average_2weeks  median_forever  median_2weeks  price  initialprice  \
# 0             709             317             26  999.0         999.0
# 1              15              62             15  499.0         499.0
# 2               0              34              0  499.0         499.0
# 3               0             184              0  499.0         499.0
# 4               0             415              0  499.0         499.0
#
#    discount                                          languages   genre    ccu  \
# 0       0.0  English, French, German, Italian, Spanish - Sp...  Action  14923
# 1       0.0  English, French, German, Italian, Spanish - Sp...  Action     87
# 2       0.0  English, French, German, Italian, Spanish - Spain  Action    130
# 3       0.0  English, French, German, Italian, Spanish - Sp...  Action      4
# 4       0.0                    English, French, German, Korean  Action     71
#
#                                                 tags
# 0  {'Action': 2681, 'FPS': 2048, 'Multiplayer': 1...
# 1  {'Action': 208, 'FPS': 188, 'Multiplayer': 172...
# 2  {'FPS': 138, 'World War II': 122, 'Multiplayer...
# 3  {'Action': 85, 'FPS': 71, 'Multiplayer': 58, '...
# 4  {'FPS': 235, 'Action': 211, 'Sci-fi': 166, 'Si...

# %%
raw_steamspy_data.isnull().sum()
# Out:
# appid                  0
# name                   5
# developer            197
# publisher            280
# score_rank         29177
# positive               0
# negative               0
# userscore              0
# owners                 0
# average_forever        0
# average_2weeks         0
# median_forever         0
# median_2weeks          0
# price                 29
# initialprice          22
# discount              22
# languages             94
# genre                152
# ccu                    0
# tags                   0
# dtype: int64

# %%
def process_tags(df): #keep top 5 tags,export rest to seperate file
 
    def parse_tags(x):
        x = literal_eval(x)
        
        if isinstance(x, dict):
            return ';'.join(list(x.keys())[:3])
        else:
            return np.nan
    
    df['tags'] = df['tags'].apply(parse_tags)
    
    # rows with null tags seem to be superseded by newer release, so remove (e.g. dead island)
    df = df[df['tags'].notnull()]
    
    return df


def process(df):
    df = df.copy()
    
    # handle missing values
    df = df[(df['name'].notnull()) & (df['name'] != 'none')]
    df = df[df['developer'].notnull()]
    df = df[df['languages'].notnull()]
    df = df[df['price'].notnull()]
    
    # remove unwanted columns
    df = df.drop([
        'genre', 'developer', 'publisher', 'score_rank', 'userscore', 'average_2weeks',
        'median_2weeks', 'price', 'initialprice', 'discount', 'ccu'
    ], axis=1)
    
    # keep top tags, exporting full tag data to file
    df = process_tags(df)
    
    # reformat owners column
    df['owners'] = df['owners'].str.replace(',', '').str.replace(' .. ', '-')
    
    return df


steamspy_data = process(raw_steamspy_data)
steamspy_data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# Exported tag data to '../data/exports/steamspy_tag_data.csv'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: FutureWarning: The default value of regex will change from True to False in a future version.
#    appid                       name  positive  negative             owners  \
# 0     10             Counter-Strike    124534      3339  10000000-20000000
# 1     20      Team Fortress Classic      3318       633   5000000-10000000
# 2     30              Day of Defeat      3416       398   5000000-10000000
# 3     40         Deathmatch Classic      1273       267   5000000-10000000
# 4     50  Half-Life: Opposing Force      5250       288   5000000-10000000
#
#    average_forever  median_forever  \
# 0            17612             317
# 1              277              62
# 2              187              34
# 3              258             184
# 4              624             415
#
#                                            languages  \
# 0  English, French, German, Italian, Spanish - Sp...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                            tags
# 0        Action;FPS;Multiplayer
# 1        Action;FPS;Multiplayer
# 2  FPS;World War II;Multiplayer
# 3        Action;FPS;Multiplayer
# 4             FPS;Action;Sci-fi

# %%
steamspy_data.isnull().sum()
# Out:
# appid              0
# name               0
# positive           0
# negative           0
# owners             0
# average_forever    0
# median_forever     0
# languages          0
# tags               0
# dtype: int64

# %%
steamspy_data.to_csv('/content/drive/MyDrive/DA Project(EDA on Steam)/steamspy_clean.csv', index=False)

# %% [markdown]
# # Merge the dataset
#
# Merging the dataset to create final ds for visualization

# %%
steam_data = pd.read_csv('/content/drive/MyDrive/DA Project(EDA on Steam)/steam_data_clean.csv')
    
merged = steam_data.merge(steamspy_data, left_on='steam_appid', right_on='appid', suffixes=('', '_steamspy'))
merged.head()
# Out:
#                         name  steam_appid  required_age          platforms  \
# 0             Counter-Strike           10             0  windows;mac;linux
# 1      Team Fortress Classic           20             0  windows;mac;linux
# 2              Day of Defeat           30             0  windows;mac;linux
# 3         Deathmatch Classic           40             0  windows;mac;linux
# 4  Half-Life: Opposing Force           50             0  windows;mac;linux
#
#                                           categories  genres  achievements  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 2              Multi-player;Valve Anti-Cheat enabled  Action             0
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action             0
#
#   release_date  price  english         developer publisher  appid  \
# 0   2000-11-01   7.19        1             Valve     Valve     10
# 1   1999-04-01   3.99        1             Valve     Valve     20
# 2   2003-05-01   3.99        1             Valve     Valve     30
# 3   2001-06-01   3.99        1             Valve     Valve     40
# 4   1999-11-01   3.99        1  Gearbox Software     Valve     50
#
#                name_steamspy  positive  negative             owners  \
# 0             Counter-Strike    124534      3339  10000000-20000000
# 1      Team Fortress Classic      3318       633   5000000-10000000
# 2              Day of Defeat      3416       398   5000000-10000000
# 3         Deathmatch Classic      1273       267   5000000-10000000
# 4  Half-Life: Opposing Force      5250       288   5000000-10000000
#
#    average_forever  median_forever  \
# 0            17612             317
# 1              277              62
# 2              187              34
# 3              258             184
# 4              624             415
#
#                                            languages  \
# 0  English, French, German, Italian, Spanish - Sp...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                            tags
# 0        Action;FPS;Multiplayer
# 1        Action;FPS;Multiplayer
# 2  FPS;World War II;Multiplayer
# 3        Action;FPS;Multiplayer
# 4             FPS;Action;Sci-fi

# %% [markdown]
# **Finalization of dataset**

# %%
# remove overlapping columns
steam_clean = merged.drop(['name_steamspy', 'languages', 'steam_appid'], axis=1)

# reindex to reorder columns
steam_clean = steam_clean[[
    'appid',
    'name',
    'release_date',
    'english',
    'developer',
    'publisher',
    'platforms',
    'required_age',
    'categories',
    'genres',
    'tags',
    'achievements',
    'positive',
    'negative',
    'average_forever',
    'median_forever',
    'owners',
    'price'
]]

steam_clean = steam_clean.rename({
    'tags': 'steamspy_tags',
    'positive': 'positive_ratings',
    'negative': 'negative_ratings',
    'average_forever': 'average_playtime',
    'median_forever': 'median_playtime'
}, axis=1)

steam_clean.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %%
steam_clean.to_csv('/content/drive/MyDrive/DA Project(EDA on Steam)/steam.csv', index=False)
